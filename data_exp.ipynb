# %% [markdown]
# # Download Data

# %%
# The code was removed by Watson Studio for sharing.

# %%
# !rm data_raw.csv
# !ls
# Out:
# 10390.png   135504501.png  241.png	6115.png  66074.png  7929.png
# 106705.png  13568.png	   243.png	6319.png  66978.png  7952.png
# 11269.png   137201.png	   24529.png	6324.png  67180.png  8033.png
# 1146.png    140746.png	   24547.png	6325.png  674.png    8053.png
# 11473.png   143710.png	   24823.png	6329.png  69319.png  8058.png
# 11638.png   144018.png	   3283.png	6335.png  74209.png  887.png
# 11646.png   14917.png	   33558.png	6360.png  74348.png  9237.png
# 12228.png   176.png	   5206.png	6375.png  7732.png   931.png
# 12246.png   177.png	   5365279.png	6386.png  77628.png  9964.png
# 123257.png  18196.png	   552549.png	6393.png  783.png    996.png
# 123502.png  222.png	   566545.png	6410.png  7845.png   BASKVILL.TTF
# 127602.png  240.png	   5962.png	6569.png  784.png

# %%
download_file_cos(credentials_1, 'data_raw.csv', 'data_raw.csv')
# !ls
# Out:
# File Downloaded
# 10390.png   135504501.png  241.png	6115.png  66074.png  7929.png
# 106705.png  13568.png	   243.png	6319.png  66978.png  7952.png
# 11269.png   137201.png	   24529.png	6324.png  67180.png  8033.png
# 1146.png    140746.png	   24547.png	6325.png  674.png    8053.png
# 11473.png   143710.png	   24823.png	6329.png  69319.png  8058.png
# 11638.png   144018.png	   3283.png	6335.png  74209.png  887.png
# 11646.png   14917.png	   33558.png	6360.png  74348.png  9237.png
# 12228.png   176.png	   5206.png	6375.png  7732.png   931.png
# 12246.png   177.png	   5365279.png	6386.png  77628.png  9964.png
# 123257.png  18196.png	   552549.png	6393.png  783.png    996.png
# 123502.png  222.png	   566545.png	6410.png  7845.png   BASKVILL.TTF
# 127602.png  240.png	   5962.png	6569.png  784.png    data_raw.csv

# %%
# !head -10 data_raw.csv
# Out:
# cid,aid1,aid2,atom1,atom2,x_1,y_1,z_1,x_2,y_2,z_2,atom1_charge,atom2_charge,bond
# 6324,1,2,C,C,-0.756,0.0,0.0,0.756,0.0,0.0,0,0,1
# 6324,1,3,C,H,-0.756,0.0,0.0,-1.1404,0.6586,0.7845,0,0,1
# 6324,1,4,C,H,-0.756,0.0,0.0,-1.1404,0.3501,-0.9626,0,0,1
# 6324,1,5,C,H,-0.756,0.0,0.0,-1.1405,-1.0087,0.1781,0,0,1
# 6324,1,6,C,H,-0.756,0.0,0.0,1.1404,-0.3501,0.9626,0,0,0
# 6324,1,7,C,H,-0.756,0.0,0.0,1.1405,1.0087,-0.1781,0,0,0
# 6324,1,8,C,H,-0.756,0.0,0.0,1.1404,-0.6586,-0.7845,0,0,0
# 6324,2,1,C,C,0.756,0.0,0.0,-0.756,0.0,0.0,0,0,0
# 6324,2,3,C,H,0.756,0.0,0.0,-1.1404,0.6586,0.7845,0,0,0

# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data=pd.read_csv('data_raw.csv')

# %%
data.head()
# Out:
#     cid  aid1  aid2 atom1 atom2    x_1  y_1  z_1     x_2     y_2     z_2  \
# 0  6324     1     2     C     C -0.756  0.0  0.0  0.7560  0.0000  0.0000
# 1  6324     1     3     C     H -0.756  0.0  0.0 -1.1404  0.6586  0.7845
# 2  6324     1     4     C     H -0.756  0.0  0.0 -1.1404  0.3501 -0.9626
# 3  6324     1     5     C     H -0.756  0.0  0.0 -1.1405 -1.0087  0.1781
# 4  6324     1     6     C     H -0.756  0.0  0.0  1.1404 -0.3501  0.9626
#
#    atom1_charge  atom2_charge  bond
# 0             0             0     1
# 1             0             0     1
# 2             0             0     1
# 3             0             0     1
# 4             0             0     0

# %%
data.shape
# Out:
# (27776, 14)

# %%
data.isna().describe(include='all').T
# Out:
#               count unique    top   freq
# cid           27776      1  False  27776
# aid1          27776      1  False  27776
# aid2          27776      1  False  27776
# atom1         27776      1  False  27776
# atom2         27776      1  False  27776
# x_1           27776      1  False  27776
# y_1           27776      1  False  27776
# z_1           27776      2  False  27774
# x_2           27776      1  False  27776
# y_2           27776      1  False  27776
# z_2           27776      2  False  27774
# atom1_charge  27776      1  False  27776
# atom2_charge  27776      1  False  27776
# bond          27776      1  False  27776

# %%
data.describe(include='all').T
# Out:
#               count unique  top   freq         mean         std      min  \
# cid           27776    NaN  NaN    NaN   1.1215e+07  3.6965e+07      176
# aid1          27776    NaN  NaN    NaN      16.8601     12.1636        1
# aid2          27776    NaN  NaN    NaN      16.8601     12.1636        1
# atom1         27776      6    H  15972          NaN         NaN      NaN
# atom2         27776      6    H  15972          NaN         NaN      NaN
# x_1           27776    NaN  NaN    NaN    0.0155816     3.27563 -11.0033
# y_1           27776    NaN  NaN    NaN    0.0135154     1.53577  -4.0991
# z_1           27774    NaN  NaN    NaN     0.040163    0.957047  -2.7548
# x_2           27776    NaN  NaN    NaN    0.0155816     3.27563 -11.0033
# y_2           27776    NaN  NaN    NaN    0.0135154     1.53577  -4.0991
# z_2           27774    NaN  NaN    NaN     0.040163    0.957047  -2.7548
# atom1_charge  27776    NaN  NaN    NaN -7.20046e-05   0.0456969       -1
# ...

# %%
data['bond'].value_counts()
# Out:
# 0    26665
# 1     1111
# Name: bond, dtype: int64

# %%
data['atom1'].unique()
# Out:
# array(['C', 'H', 'N', 'O', 'F', 'Si'], dtype=object)

# %%
data['atom2'].unique()
# Out:
# array(['C', 'H', 'N', 'O', 'F', 'Si'], dtype=object)

# %%
data['cid'].nunique()
# Out:
# 70

# %%
plt.figure(figsize=(12,7))
plt.scatter(data['cid'].apply(str),data['bond'],c=data['bond'])
plt.xticks(rotation='vertical');
