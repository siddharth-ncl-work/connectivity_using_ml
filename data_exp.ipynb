# %% [markdown]
# # Download Data

# %%
# The code was removed by Watson Studio for sharing.

# %%
# !rm data.csv
# !ls
# Out:
# rm: cannot remove ‘data.csv’: No such file or directory
# 11269.png   127602.png	   177.png    24823.png   6325.png  6410.png   7929.png
# 1146.png    135504501.png  222.png    3283.png	  6329.png  6569.png   8033.png
# 11473.png   13568.png	   240.png    33558.png   6335.png  67180.png  8053.png
# 11638.png   137201.png	   241.png    5206.png	  6360.png  674.png    8058.png
# 11646.png   140746.png	   243.png    552549.png  6375.png  69319.png  887.png
# 12228.png   14917.png	   24529.png  6115.png	  6386.png  7845.png   931.png
# 123257.png  176.png	   24547.png  6324.png	  6393.png  784.png    996.png

# %%
download_file_cos(credentials_1, 'data.csv', 'data.csv')
# !ls
# Out:
# File Downloaded
# 11269.png   135504501.png  240.png    5206.png	  6375.png   7845.png  996.png
# 1146.png    13568.png	   241.png    552549.png  6386.png   784.png   data.csv
# 11473.png   137201.png	   243.png    6115.png	  6393.png   7929.png
# 11638.png   140746.png	   24529.png  6324.png	  6410.png   8033.png
# 11646.png   14917.png	   24547.png  6325.png	  6569.png   8053.png
# 12228.png   176.png	   24823.png  6329.png	  67180.png  8058.png
# 123257.png  177.png	   3283.png   6335.png	  674.png    887.png
# 127602.png  222.png	   33558.png  6360.png	  69319.png  931.png

# %%
# !head -10 data.csv
# Out:
# cid,aid1,aid2,atom1,atom2,x_1,y_1,z_1,x_2,y_2,z_2,atom1_charge,atom2_charge,bond
# 6324,1,2,C,C,-0.756,0.0,0.0,0.756,0.0,0.0,0,0,1
# 6324,1,3,C,H,-0.756,0.0,0.0,-1.1404,0.6586,0.7845,0,0,1
# 6324,1,4,C,H,-0.756,0.0,0.0,-1.1404,0.3501,-0.9626,0,0,1
# 6324,1,5,C,H,-0.756,0.0,0.0,-1.1405,-1.0087,0.1781,0,0,1
# 6324,1,6,C,H,-0.756,0.0,0.0,1.1404,-0.3501,0.9626,0,0,0
# 6324,1,7,C,H,-0.756,0.0,0.0,1.1405,1.0087,-0.1781,0,0,0
# 6324,1,8,C,H,-0.756,0.0,0.0,1.1404,-0.6586,-0.7845,0,0,0
# 6324,2,1,C,C,0.756,0.0,0.0,-0.756,0.0,0.0,0,0,0
# 6324,2,3,C,H,0.756,0.0,0.0,-1.1404,0.6586,0.7845,0,0,0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data=pd.read_csv('data.csv')

# %%
data.head()
# Out:
#     cid  aid1  aid2 atom1 atom2    x_1  y_1  z_1     x_2     y_2     z_2  \
# 0  6324     1     2     C     C -0.756  0.0  0.0  0.7560  0.0000  0.0000
# 1  6324     1     3     C     H -0.756  0.0  0.0 -1.1404  0.6586  0.7845
# 2  6324     1     4     C     H -0.756  0.0  0.0 -1.1404  0.3501 -0.9626
# 3  6324     1     5     C     H -0.756  0.0  0.0 -1.1405 -1.0087  0.1781
# 4  6324     1     6     C     H -0.756  0.0  0.0  1.1404 -0.3501  0.9626
#
#    atom1_charge  atom2_charge  bond
# 0             0             0     1
# 1             0             0     1
# 2             0             0     1
# 3             0             0     1
# 4             0             0     0

# %%
data.shape
# Out:
# (9058, 14)

# %%
data.isna().describe(include='all').T
# Out:
#              count unique    top  freq
# cid           9058      1  False  9058
# aid1          9058      1  False  9058
# aid2          9058      1  False  9058
# atom1         9058      1  False  9058
# atom2         9058      1  False  9058
# x_1           9058      1  False  9058
# y_1           9058      1  False  9058
# z_1           9058      1  False  9058
# x_2           9058      1  False  9058
# y_2           9058      1  False  9058
# z_2           9058      1  False  9058
# atom1_charge  9058      1  False  9058
# atom2_charge  9058      1  False  9058
# bond          9058      1  False  9058

# %%
data.describe(include='all').T
# Out:
#              count unique  top  freq         mean        std      min     25%  \
# cid           9058    NaN  NaN   NaN  3.37748e+07  5.859e+07      176    6360
# aid1          9058    NaN  NaN   NaN      12.8754    10.9641        1       5
# aid2          9058    NaN  NaN   NaN      12.8754    10.9641        1       5
# atom1         9058      6    H  4706          NaN        NaN      NaN     NaN
# atom2         9058      6    H  4706          NaN        NaN      NaN     NaN
# x_1           9058    NaN  NaN   NaN   -0.0416598    3.70724 -11.0033 -1.8442
# y_1           9058    NaN  NaN   NaN  -0.00378194    1.24764  -2.7437 -1.0267
# z_1           9058    NaN  NaN   NaN    0.0134692   0.789915  -2.0395  -0.432
# x_2           9058    NaN  NaN   NaN   -0.0416598    3.70724 -11.0033 -1.8442
# y_2           9058    NaN  NaN   NaN  -0.00378194    1.24764  -2.7437 -1.0267
# z_2           9058    NaN  NaN   NaN    0.0134692   0.789915  -2.0395  -0.432
# atom1_charge  9058    NaN  NaN   NaN -0.000220799   0.080024       -1       0
# atom2_charge  9058    NaN  NaN   NaN -0.000220799   0.080024       -1       0
# bond          9058    NaN  NaN   NaN    0.0586222   0.234929        0       0
#
#                  50%     75%          max
# cid             8058  552549  1.35505e+08
# aid1              10      17           48
# aid2              10      17           48
# atom1            NaN     NaN          NaN
# atom2            NaN     NaN          NaN
# x_1          -0.0774  1.8546      11.0034
# y_1                0  1.0388       2.8417
# z_1                0  0.3747       2.3664
# x_2          -0.0774  1.8546      11.0034
# y_2                0  1.0388       2.8417
# z_2                0  0.3747       2.3664
# atom1_charge       0       0            1
# atom2_charge       0       0            1
# bond               0       0            1

# %%
data['bond'].value_counts()
# Out:
# 0    8527
# 1     531
# Name: bond, dtype: int64

# %%
data['atom1'].unique()
# Out:
# array(['C', 'H', 'N', 'O', 'F', 'Si'], dtype=object)

# %%
data['atom2'].unique()
# Out:
# array(['C', 'H', 'N', 'O', 'F', 'Si'], dtype=object)

# %%
data['cid'].nunique()
# Out:
# 49

# %%
plt.figure(figsize=(12,7))
plt.scatter(data['cid'].apply(str),data['bond'],c=data['bond'])
plt.xticks(rotation='vertical');
